# %% [markdown]
# # Step1: Choose Sagemaker base image

# %%
import sagemaker

# Define the framework details
framework = 'sklearn'
version = '1.2-1'  
region = 'us-east-2'  

# Retrieve the base image URI
image_uri = sagemaker.image_uris.retrieve(
    framework=framework,
    region=region,
    version=version,
    image_scope='training',  # Use 'inference' for inference images
    instance_type='ml.c5.xlarge' 
)

print(image_uri)
# Out:
# 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3

# %% [markdown]
# # Step2: Write your Dockerfile

# %% [markdown]
# # Step3: Build the Custom Image

# %% [markdown]
# # Step4: Push Image to Container Registry

# %% [markdown]
# # Step5: Train Model Using Custom Image

# %%
from sagemaker.sklearn import SKLearn
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session()

# %% [markdown]
# ### Training using sagemaker base image

# %%
base_image_uri = "257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3"
sk_estimator = SKLearn(
    entry_point="train.py",
    role=role,
    instance_count=1,
    instance_type="ml.c5.xlarge",
    image_uri=base_image_uri,
    sagemaker_session=sagemaker_session,
    hyperparameters={"n_estimators":4},
)
# Train the estimator
training_input_path = "s3://modeldata1234567/train/train.csv"
sk_estimator.fit({"train": training_input_path})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2024-08-21-12-39-36-499
# 2024-08-21 12:39:36 Starting - Starting the training job...
# 2024-08-21 12:39:51 Starting - Preparing the instances for training...
# 2024-08-21 12:40:25 Downloading - Downloading the training image.....2024-08-21 12:41:15,872 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-08-21 12:41:15,874 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 12:41:15,877 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 12:41:15,894 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-08-21 12:41:16,144 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 12:41:16,147 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 12:41:16,163 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 12:41:16,166 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 12:41:16,182 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 12:41:16,184 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 12:41:16,198 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.c5.xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n_estimators": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.c5.xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "sagemaker-scikit-learn-2024-08-21-12-39-36-499",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-08-21-12-39-36-499/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n_estimators":4}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.c5.xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-08-21-12-39-36-499/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.c5.xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n_estimators":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"sagemaker-scikit-learn-2024-08-21-12-39-36-499","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-08-21-12-39-36-499/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--n_estimators","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_N_ESTIMATORS=4
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train.py --n_estimators 4
# 2024-08-21 12:41:16,198 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-08-21 12:41:16,198 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# matplotlib is not available.
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 115  6.4  3.2  5.3  2.3
# 116  6.5  3.0  5.5  1.8
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 119  6.0  2.2  5.0  1.5
# [120 rows x 4 columns]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    2
# 116    2
# 117    2
# 118    2
# 119    2
# Name: 4, Length: 120, dtype: int64
# 2024-08-21 12:41:17,131 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-08-21 12:41:35 Training - Training image download completed. Training in progress.
# 2024-08-21 12:41:35 Uploading - Uploading generated training model
# 2024-08-21 12:41:35 Completed - Training job completed
# Training seconds: 84
# Billable seconds: 84

# %% [markdown]
# ### Training using extended/custom sagemaker image

# %%
custom_image_uri = "930627915954.dkr.ecr.us-east-2.amazonaws.com/custom-sagemaker-sklearn-training-container:latest"
sk_estimator = SKLearn(
    entry_point="train.py",
    role=role,
    instance_count=1,
    instance_type="ml.c5.xlarge",
    image_uri=custom_image_uri,
    sagemaker_session=sagemaker_session,
    hyperparameters={"n_estimators":4},
)
# Train the estimator
training_input_path = "s3://modeldata1234567/train/train.csv"
sk_estimator.fit({"train": training_input_path})
# Out:
# INFO:sagemaker:Creating training-job with name: custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829
# 2024-08-21 13:00:24 Starting - Starting the training job...
# 2024-08-21 13:00:39 Starting - Preparing the instances for training...
# 2024-08-21 13:01:19 Downloading - Downloading the training image......
# 2024-08-21 13:02:15 Training - Training image download completed. Training in progress.
# 2024-08-21 13:02:15 Uploading - Uploading generated training model2024-08-21 13:02:08,501 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-08-21 13:02:08,504 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 13:02:08,506 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 13:02:08,523 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-08-21 13:02:08,526 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 13:02:08,528 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 13:02:08,548 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 13:02:08,550 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 13:02:08,566 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-21 13:02:08,568 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-21 13:02:08,581 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.c5.xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n_estimators": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.c5.xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-930627915954/custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n_estimators":4}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.c5.xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-930627915954/custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.c5.xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n_estimators":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-930627915954/custom-sagemaker-sklearn-training-conta-2024-08-21-13-00-23-829/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--n_estimators","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_N_ESTIMATORS=4
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python train.py --n_estimators 4
# 2024-08-21 13:02:08,581 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-08-21 13:02:08,582 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# matplotlib is available.
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 115  6.4  3.2  5.3  2.3
# 116  6.5  3.0  5.5  1.8
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 119  6.0  2.2  5.0  1.5
# [120 rows x 4 columns]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    2
# 116    2
# 117    2
# 118    2
# 119    2
# Name: 4, Length: 120, dtype: int64
# 2024-08-21 13:02:10,026 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-08-21 13:02:28 Completed - Training job completed
# Training seconds: 89
# Billable seconds: 89
